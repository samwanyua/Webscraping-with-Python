# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in the United States by revenue - Wikipedia</title>
# ...

# %%
# specify the data we are looking for
# <table class="wikitable sortable jquery-tablesorter">
table = soup.find('table', class_ = 'wikitable sortable')
table
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">648,125
# </td>
# ...

# %%
world_titles = table.find_all('th')
world_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
# List comprehension
word_table_titles = [title.text.strip() for title in world_titles]
word_table_titles
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue (USD millions)',
#  'Revenue growth',
#  'Employees',
#  'Headquarters']

# %%
# put into a pandas dataframe
import pandas as pd
df = pd.DataFrame(columns= word_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                  Name                    Industry  \
# 0     1               Walmart                      Retail
# 1     2                Amazon  Retail and cloud computing
# 2     3                 Apple        Electronics industry
# 3     4    UnitedHealth Group                  Healthcare
# 4     5    Berkshire Hathaway                Conglomerate
# ..  ...                   ...                         ...
# 95   96                  TIAA                  Financials
# 96   97                   CHS     Agriculture cooperative
# 97   98  Bristol-Myers Squibb     Pharmaceutical industry
# 98   99  Dow Chemical Company           Chemical industry
# 99  100              Best Buy                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 648,125           6.0%  2,100,000
# 1                 574,785          11.9%  1,525,000
# 2                 383,482          -2.8%    161,000
# 3                 371,622          14.6%    440,000
# ...

# %%
df.to_csv('/home/wanyua/Programming/ML/Webscraping-with-Python/Top_100_companies.csv', index=False, header=True, encoding='utf-8')

# %%
df.shape
# Out:
# (100, 7)

# %%
df.head()
# Out:
#   Rank                Name                    Industry Revenue (USD millions)  \
# 0    1             Walmart                      Retail                648,125
# 1    2              Amazon  Retail and cloud computing                574,785
# 2    3               Apple        Electronics industry                383,482
# 3    4  UnitedHealth Group                  Healthcare                371,622
# 4    5  Berkshire Hathaway                Conglomerate                364,482
#
#   Revenue growth  Employees           Headquarters
# 0           6.0%  2,100,000  Bentonville, Arkansas
# 1          11.9%  1,525,000    Seattle, Washington
# 2          -2.8%    161,000  Cupertino, California
# 3          14.6%    440,000  Minnetonka, Minnesota
# 4          20.7%    396,500        Omaha, Nebraska

# %% [markdown]
# Get a summary of the DataFrame, including column types and non-null counts.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    object
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %% [markdown]
# View basic statistics for numerical columns.

# %%
df.describe()
# Out:
#        Rank     Name    Industry Revenue (USD millions) Revenue growth  \
# count   100      100         100                    100            100
# unique  100      100          37                     98             96
# top       1  Walmart  Financials                 54,317           4.8%
# freq      1        1          13                      2              2
#
#        Employees             Headquarters
# count        100                      100
# unique        98                       72
# top      226,000  New York City, New York
# freq           2                       13

# %% [markdown]
# Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# Rank                      0
# Name                      0
# Industry                  0
# Revenue (USD millions)    0
# Revenue growth            0
# Employees                 0
# Headquarters              0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# We can visualize missing data on a heatmap by the following
# ```sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# plt.title("Missing Values Heatmap")
# plt.show()```

# %% [markdown]
# Exploring the Distribution of Features

# %%
# Remove any non-numeric characters and convert to numeric
df['Revenue (USD millions)'] = pd.to_numeric(df['Revenue (USD millions)'].str.replace(',', ''), errors='coerce')
df['Revenue growth'] = pd.to_numeric(df['Revenue growth'].str.replace('%', ''), errors='coerce')
df['Employees'] = pd.to_numeric(df['Employees'].str.replace(',', ''), errors='coerce')

# %%
# Plot histograms for numerical features
fig, axes = plt.subplots(2, 2, figsize=(12, 6))

sns.histplot(df['Revenue (USD millions)'], bins=20, ax=axes[0, 0], kde=True)
axes[0, 0].set_title('Revenue Distribution')
axes[0, 0].set_xlabel('Revenue (USD millions)')

sns.histplot(df['Revenue growth'], bins=20, ax=axes[0, 1], kde=True)
axes[0, 1].set_title('Revenue Growth Distribution')
axes[0, 1].set_xlabel('Revenue Growth')

sns.histplot(df['Employees'], bins=20, ax=axes[1, 0], kde=True)
axes[1, 0].set_title('Employee Count Distribution')
axes[1, 0].set_xlabel('Number of Employees')

fig.delaxes(axes[1, 1])  

plt.tight_layout()  
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    object
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    int64
#  4   Revenue growth          100 non-null    float64
#  5   Employees               100 non-null    int64
#  6   Headquarters            100 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.2+ KB

# %% [markdown]
# Categorical Analysis
# Analyzing the distribution of categorical features can reveal the most common categories and their frequencies. Let's look at the distributions of Industry and Headquarters.

# %%
# Plotting count of companies by Industry
plt.figure(figsize=(12, 6))
sns.countplot(y='Industry', data=df, order=df['Industry'].value_counts().index)
plt.title('Number of Companies by Industry')
plt.xlabel('Number of Companies')
plt.ylabel('Industry')
plt.show()

# Plotting count of companies by Headquarters
plt.figure(figsize=(12, 6))
sns.countplot(y='Headquarters', data=df, order=df['Headquarters'].value_counts().index[:10]) # Display top 10
plt.title('Number of Companies by Headquarters (Top 10)')
plt.xlabel('Number of Companies')
plt.ylabel('Headquarters')
plt.show()

# %% [markdown]
# Correlation Analysis
# Correlation analysis will help understand the relationships between numerical features. We can use a heatmap to visualize the correlation matrix.

# %%
# Select only the numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Now calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    object
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    int64
#  4   Revenue growth          100 non-null    float64
#  5   Employees               100 non-null    int64
#  6   Headquarters            100 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.2+ KB

# %% [markdown]
# Outlier Detection
# To identify any potential outliers in numerical features, we can use box plots

# %%
# Plotting box plots for numerical features
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.boxplot(y='Revenue (USD millions)', data=df, ax=axes[0])
axes[0].set_title('Revenue (USD millions) Box Plot')

sns.boxplot(y='Revenue growth', data=df, ax=axes[1])
axes[1].set_title('Revenue Growth Box Plot')

sns.boxplot(y='Employees', data=df, ax=axes[2])
axes[2].set_title('Employees Box Plot')

plt.tight_layout()
plt.show()
